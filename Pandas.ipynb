# %%
import pandas as pd

# %%
data = pd.read_csv('onlinefoods.csv')

# %%
data.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
data.tail()
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 383              Post Graduate            2   12.9766    77.5993    560001
# 384              Post Graduate            4   12.9854    77.7081    560048
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#     Output  Feedback Unnamed: 12
# 383    Yes  Positive         Yes
# 384    Yes  Positive         Yes
# 385    Yes  Positive         Yes
# ...

# %%
data.shape
# Out:
# (388, 13)

# %%
data.iloc[:3]
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes

# %%
data.iloc[-3: , :2]
# Out:
#      Age  Gender
# 385   22  Female
# 386   23    Male
# 387   23    Male

# %%
data[data['Gender'] == 'Female']
# Out:
#      Age  Gender Marital Status Occupation   Monthly Income  \
# 0     20  Female         Single    Student        No Income
# 1     24  Female         Single    Student   Below Rs.10000
# 3     22  Female         Single    Student        No Income
# 5     27  Female        Married   Employee  More than 50000
# 7     24  Female         Single    Student        No Income
# ..   ...     ...            ...        ...              ...
# 380   27  Female        Married   Employee  More than 50000
# 382   24  Female         Single    Student        No Income
# 383   23  Female         Single    Student        No Income
# 384   23  Female         Single    Student        No Income
# 385   22  Female         Single    Student        No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
data['Gender'] = data['Gender'].replace(['Female', 'Male'], ['F','M'])

# %%
data[data['Gender'] == 'F']
# Out:
#      Age Gender Marital Status Occupation   Monthly Income  \
# 0     20      F         Single    Student        No Income
# 1     24      F         Single    Student   Below Rs.10000
# 3     22      F         Single    Student        No Income
# 5     27      F        Married   Employee  More than 50000
# 7     24      F         Single    Student        No Income
# ..   ...    ...            ...        ...              ...
# 380   27      F        Married   Employee  More than 50000
# 382   24      F         Single    Student        No Income
# 383   23      F         Single    Student        No Income
# 384   23      F         Single    Student        No Income
# 385   22      F         Single    Student        No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
data.rename(columns={'Age': 'Yaş', 'Gender': 'Cinsiyet'}, inplace=True)

# %%
data
# Out:
#      Yaş Cinsiyet Marital Status Occupation  Monthly Income  \
# 0     20        F         Single    Student       No Income
# 1     24        F         Single    Student  Below Rs.10000
# 2     22        M         Single    Student  Below Rs.10000
# 3     22        F         Single    Student       No Income
# 4     22        M         Single    Student  Below Rs.10000
# ..   ...      ...            ...        ...             ...
# 383   23        F         Single    Student       No Income
# 384   23        F         Single    Student       No Income
# 385   22        F         Single    Student       No Income
# 386   23        M         Single    Student  Below Rs.10000
# 387   23        M         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
data['Yaş'].min()
# Out:
# 18

# %%
data['Yaş'].max()
# Out:
# 33

# %%
data['Yaş'].mean()
# Out:
# np.float64(24.628865979381445)

# %%
data['Yaş'].count()
# Out:
# np.int64(388)

# %%
data['Cinsiyet'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
data['Cinsiyet'].value_counts()
# Out:
# Cinsiyet
# M    222
# F    166
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# Yaş                           0
# Cinsiyet                      0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# Unnamed: 12                   0
# dtype: int64

# %%
data.head()
# Out:
#    Yaş Cinsiyet Marital Status Occupation  Monthly Income  \
# 0   20        F         Single    Student       No Income
# 1   24        F         Single    Student  Below Rs.10000
# 2   22        M         Single    Student  Below Rs.10000
# 3   22        F         Single    Student       No Income
# 4   22        M         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
data.drop_duplicates()
# Out:
#      Yaş Cinsiyet Marital Status Occupation   Monthly Income  \
# 0     20        F         Single    Student        No Income
# 1     24        F         Single    Student   Below Rs.10000
# 2     22        M         Single    Student   Below Rs.10000
# 3     22        F         Single    Student        No Income
# 4     22        M         Single    Student   Below Rs.10000
# ..   ...      ...            ...        ...              ...
# 355   21        M         Single    Student        No Income
# 363   31        M        Married   Employee  More than 50000
# 369   30        M        Married   Employee  More than 50000
# 374   21        M         Single    Student        No Income
# 386   23        M         Single    Student   Below Rs.10000
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

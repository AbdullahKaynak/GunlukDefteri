# %% [markdown]
# # 4 tip objects(Nesneler) vardır

# %% [markdown]
# 1 - List -> type( [1, 34 ,3] )
#
# 2 - İnt  -> type (1)
#
# 3 - Str  -> type("The cat is yellow")
#
# 4 - Dict -> type({ "dog": 1, "Cat": 2} )
